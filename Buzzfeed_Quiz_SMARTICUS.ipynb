# %% [markdown]
# <a href="https://colab.research.google.com/github/sanaasharda23/SMARTICUS-/blob/main/Buzzfeed_Quiz_SMARTICUS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to SMARTICUS :)")                           #name of game
print('''RULES:
- Quiz 1: Movies ; Quiz 2: Dorm Food ; Quiz 3: Songs. 
- Please enter option numbers only (1,2,3,4).
- To exit a specific quiz at any time press Q or q.
- To exit the entire game, press any key except 1,2,3 when quiz number option is asked ''')
while True:
  x=input("Please choose quiz number(1/2/3):")
  if x=="1":
      while True:
        print("*"*40)
        pts=0
        print("Quiz 1")
        print("Throw yourself a feast and we'll suggest you a movie to watch!")    #quiz topic 1
        print()
        q1=input('''Choose some breakfast                                  
1. Avocado toast
2. Breakfast burrito
3. Croissant
4. Waffles & Pancakes
-->''')
        if q1=="1":
            pts+=3
        elif q1=="2":
            pts+=2
        elif q1=="3":
            pts+=4
        elif q1=="4":
            pts+=1
        elif q1=="q" or q1=="Q":
            break
        else:
            print('Sorry, invalid input!')
            print("Quiz will start again")
            continue
        
        q2=input('''Time for lunch!
1. Quesadilla
2. Pizza
3. Falafel Wrap
4. Sandwich
-->''')
        if q2=="1":
            pts+=2
        elif q2=="2":
            pts+=1
        elif q2=="3":
            pts+=3
        elif q2=="4":
            pts+=4
        elif q2=="q" or q2=="Q":
            break
        else:
            print('Sorry, invalid input!')
            print("Quiz will start again")
            continue

        q3=input('''What's for dinner?
1. Burger
2. Lasagna
3. Tacos
4. Stir fried tofu with rice
-->''')
        if q3=="1":
            pts+=1
        elif q3=="2":
            pts+=4
        elif q3=="3":
            pts+=2
        elif q3=="4":
            pts+=3
        elif q3=="q" or q3=="Q":
            break
        else:
            print('Sorry, invalid input!')
            print("Quiz will start again")
            continue

        q4=input('''Let's not forget dessert
1. Tiramisu
2. Brownies
3. Ice cream
4. Cheesecake
-->''')
        if q4=="1":
            pts+=3
        elif q4=="2":
            pts+=1
        elif q4=="3":
            pts+=4
        elif q4=="4":
            pts+=2
        elif q4=="q" or q4=="Q":
            break
        else:
            print('Sorry, invalid input!')
            print("Quiz will start again")
            continue

        q5=input('''Oh! Midnight cravings. What do you pick?
1. Chips and dip
2. Cookies
3. Instant noodles
4. Popcorn
-->''')
        if q5=="1":
            pts+=4
        elif q5=="2":
            pts+=1
        elif q5=="3":
            pts+=3
        elif q5=="4":
            pts+=2
        elif q5=="q" or q5=="Q":
            break
        else:
            print('Sorry, invalid input!')
            print("Quiz will start again")
            continue

        q6=input('''Where would you travel to for the perfect meal?
1. France
2. Italy
3. Mexico
4. USA
-->''')
        if q6=='1':
            pts+=2
        elif q6=='2':
            pts+=3
        elif q6=='3':
            pts+=4
        elif q6=='4':
            pts+=1
        elif q6=="q" or q6=="Q":
            break
        else:
            print('Sorry, invalid input!')
            print("Quiz will start again")
            continue
        
        print("*"*40)
        print("Grab your favourite drink and watch--")
        if pts<=6:                                                               #point based movies recommended
            print('''       < THE INCREDIBLES >
What can i say except "NO CAPES!" ''')
        elif pts>6 and pts<=9:
            print('''     < RATATOUILLE >
Bring out the inner chef in you''')
        elif pts>9 and pts<=12:
            print('''       < HOME ALONE >
A Christmas classic   ''')
        elif pts>12 and pts<=15:
            print('''< THE DEVIL WEARS PRADA >
"That's all"           ''')
        elif pts>15 and pts<=18:
            print('''        < KNIVES OUT >
Everyone has a motive. No one has a clue''')
        elif pts>18 and pts<=21:
            print('''        < INCEPTION >
Your mind is the scene of the crime''')
        elif pts>21 and pts<=24:
            print('''          < SPEED >
Get ready for rush hour ''')
        break

  elif x=="2":           
   while True:
        a=0
        print("*"*40)
        print("Quiz 2")
        print("Which Dorm Room Food are you ?!")                                   #quiz topic 2
        print() 
        Q1=input('''What time do you sleep on the weekdays ?
1. 11pm-12am
2. 12-1am
3. 1-2am
4. 2-3am
--->:''')
        if Q1=="1":
                a+=4
        elif Q1=="2":
                a+=3
        elif Q1=="3":
                a+=2
        elif Q1=="4":
                a+=1
        elif Q1=="q" or Q1=="Q":
            break
        else:
            print('Sorry, invalid input!')
            print("Quiz will start again")
            continue

        Q2=input('''What is your favourite meal of the day ?
1.Breakfast
2.Lunch
3.Snack 
4.Dinner
--->:''')
        if Q2=='1':
                a+=1
        elif Q2=='2':
                a+=2
        elif Q2=='3':
                a+=3
        elif Q2=="4":
                a+=4
        elif Q2=="q" or Q2=="Q":
            break
        else:
            print('Sorry, invalid input!')
            print("Quiz will start again")
            continue

        Q3=input('''How do you describe yourself?
1.Busy
2.Carefree
3.Opinionated
4.Optimistic
--->:''')
        if Q3=='1':
                a+=2
        elif Q3=="2":
                a+=4
        elif Q3=="3":
                a+=3
        elif Q3=="4":
                a+=1
        elif Q3=="q" or Q3=="Q":
            break
        else:
            print('Sorry, invalid input!')
            print("Quiz will start again")
            continue

        Q4=input('''What's your favourite subject ?
1.English Literature
2.Maths
3.Computer Science
4.Physics
--->:''')
        if Q4=="1":
                a+=3
        elif Q4=="2":
                a+=4
        elif Q4=="3":
                a+=1
        elif Q4=="4":
                a+=2
        elif Q4=="q" or Q4=="Q":
            break
        else:
            print('Sorry, invalid input!')
            print("Quiz will start again")
            continue
        Q5=input('''What's your favourite show?
1.Gilmore Girls
2.The Office (American)
3.Friends
4.Breaking Bad
--->:''')
        if Q5=="1":
                a+=1
        elif Q5=="2":
                a+=4
        elif Q5=="3":
                a+=2
        elif Q5=="4":
                a+=3
        elif Q1=="q" or Q1=="Q":
            break
        else:
            print('Sorry, invalid input!')
            print("Quiz will start again")
            continue
        print("*"*40)
        print("YOU ARE---")
        if a<=5:                                                                   #point based food allotted
            print('''        PIZZA ROLLS                                           
    You are the life of the party and you radiate good vibes!''')
        elif a<=10:
            print('''        MAC & CHEESE
You like to go with the flow and live in the moment!''')
        elif a<=15:
            print('''       PEANUT BUTTER & JELLY
You are always very busy and you don't like to procrastinate!''')
        elif a<=20:
                print(''' CUP NOODLES
Even though you are a little salty, you are full of spice!''')
        break
  elif x=="3":
   while True:
        pts=0
        print("*"*40)
        print("Quiz 3")
        print("Feeling bored? Take this quiz and we'll tell you a song to listen to!")    #quiz topic 3
        print()
        q1=input('''Choose your favourite genre of music                                 
1. Metal
2. Rock
3. Pop
4. Rap
-->''')
        if q1=="1":
            pts+=3
        elif q1=="2":
            pts+=2
        elif q1=="3":
            pts+=4
        elif q1=="4":
            pts+=1
        elif q1=="q" or q1=="Q":
            break
        else:
            print('Sorry, invalid input!')
            print("Quiz will start again")
            continue
        
        q2=input('''Choose your favourite colour 
1. Blue
2. Green
3. Red
4. Black 
-->''')
        if q2=="1":
            pts+=2
        elif q2=="2":
            pts+=1
        elif q2=="3":
            pts+=3
        elif q2=="4":
            pts+=4
        elif q2=="q" or q2=="Q":
            break
        else:
            print('Sorry, invalid input!')
            print("Quiz will start again")
            continue

        q3=input('''What emotion are you feeling right now ?
1. Love
2. Anxiety 
3. Nostalgia
4. Curiosity 
-->''')
        if q3=="1":
            pts+=1
        elif q3=="2":
            pts+=4
        elif q3=="3":
            pts+=2
        elif q3=="4":
            pts+=3
        elif q3=="q" or q3=="Q":
            break
        else:
            print('Sorry, invalid input!')
            print("Quiz will start again")
            continue

        q4=input('''What's your favourite animal?
1. Dog
2. Cat
3. Horse
4. Rabbit 
-->''')
        if q4=="1":
            pts+=3
        elif q4=="2":
            pts+=1
        elif q4=="3":
            pts+=4
        elif q4=="4":
            pts+=2
        elif q4=="q" or q4=="Q":
            break
        else:
            print('Sorry, invalid input!')
            print("Quiz will start again")
            continue
        q5=input('''Choose your favourite artist 
1. The Weeknd
2. Queen 
3. Harry Styles
4. Guns N' Roses
-->''')
        if q5=="1":
            pts+=4
        elif q5=="2":
            pts+=1
        elif q5=="3":
            pts+=3
        elif q5=="4":
            pts+=2
        elif q5=="q" or q5=="Q":
            break
        else:
            print('Sorry, invalid input!')
            print("Quiz will start again")
            continue
        print("*"*40)
        print("THE SONG IS---")
        if pts<=5:                                                               #point based songs recommended
            print('''      <I WANT IT THAT WAY- BACKSTREET BOYS>
"Now,  number 5!" ''')
        elif pts<=10:
            print('''     <WHERE YOU LEAD, I WILL FOLLOW- COROLE KING>
Remember your best friend ''')
        elif pts<=15:
            print('''     <STAYING ALIVE - BEE GEES>
That's what we are doing in 2020! ''')
        elif pts<=20:
            print(''' <BOHEMIAN RHAPSODY- QUEEN>
Wish to escape from reality ?!        ''')
        break
  else:
    break
print("*"*40)           
print("Thank you for playing!")
